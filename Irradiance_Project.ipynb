# %%
import numpy as np
import requests

# %%
response = requests.get('https://raw.githubusercontent.com/Amitangshu/Irradiance_sensing/master/All_Data_For_EPIC_Roof/MDA300n150.dat')

# %%
data = response.text

# %%
import pandas as pd
data = data.splitlines()

# %%
import json
from pandas.io.json import json_normalize
data
# Out:
# ['%"TOA5","WIRELESSME NODE150","DATA"',
#  '"TMSTAMP","RECNBR","PARENT","IRRADIANCE","SOLAROCV","VBATT","TEMP"',
#  '"2012-09-14 18:53:15",1,0,   40.83,0.95,3.06,85.44',
#  '"2012-09-14 18:55:12",2,0,   40.83,0.96,3.05,85.35',
#  '"2012-09-14 19:04:01",3,0,   17.50,0.89,3.05,83.80',
#  '"2012-09-14 19:04:59",4,0,   17.50,0.88,3.06,83.57',
#  '"2012-09-14 19:05:57",5,0,   14.58,0.89,3.06,83.34',
#  '"2012-09-14 19:06:55",6,0,   14.58,0.90,3.06,83.15',
#  '"2012-09-14 19:08:52",7,0,   11.67,0.90,3.06,82.69',
#  '"2012-09-14 19:09:51",8,0,   11.67,0.97,3.06,82.46',
#  '"2012-09-14 19:10:49",9,0,   11.67,0.98,3.06,82.25',
#  '"2012-09-14 19:11:49",10,0,   11.67,0.98,3.06,81.99',
#  '"2012-09-14 19:12:47",11,0,   11.67,0.98,3.06,81.84',
#  '"2012-09-14 19:13:46",12,0,   11.67,0.99,3.06,81.58',
#  '"2012-09-14 19:14:44",13,0,   11.67,0.90,3.06,81.39',
#  '"2012-09-14 19:15:44",14,0,   11.67,0.92,3.06,81.16',
#  '"2012-09-14 19:16:43",15,0,   11.67,0.92,3.06,80.98',
# ...

# %%
data.remove(data[0])

# %%
headers = data[0]
headers
# Out:
# '"TMSTAMP","RECNBR","PARENT","IRRADIANCE","SOLAROCV","VBATT","TEMP"'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-5f41fe7affad> in <module>
# ----> 1 data = pd.DataFrame(data, dtype=String)
#
# NameError: name 'String' is not defined

# %%
data.head()
# Out:
#                                                    0
# 0  "TMSTAMP","RECNBR","PARENT","IRRADIANCE","SOLA...
# 1  "2012-09-14 18:53:15",1,0,   40.83,0.95,3.06,8...
# 2  "2012-09-14 18:55:12",2,0,   40.83,0.96,3.05,8...
# 3  "2012-09-14 19:04:01",3,0,   17.50,0.89,3.05,8...
# 4  "2012-09-14 19:04:59",4,0,   17.50,0.88,3.06,8...
